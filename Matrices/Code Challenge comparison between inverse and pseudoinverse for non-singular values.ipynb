# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#step 1, defining matrix size
rows = 5
columns = 5
matrix = np.random.randint(100, size=(rows, columns))

inverse = np.linalg.inv(matrix)

pseudoinverse = np.linalg.pinv(matrix)

plt.subplot(331)
plt.imshow(matrix), plt.axis('off')
plt.title('Original matrix')



plt.subplot(332)
plt.imshow(inverse), plt.axis('off')
plt.title('Inverse matrix')


plt.subplot(333)
plt.imshow(pseudoinverse), plt.axis('off')
plt.title('Pseudoinverse matrix')

plt.subplot(334)
plt.imshow(matrix@pseudoinverse), plt.axis('off')
plt.title('Matrix*Pseudoinverse')

plt.subplot(335)
plt.imsho...:image/png;base64,......w(matrix@inverse), plt.axis('off')
plt.title('Matrix*Inverse')
# Out:
# Text(0.5, 1.0, 'Matrix*Inverse')

# %%
inverse
# Out:
# array([[ 0.00251823,  0.00400527,  0.01148019, -0.00344694, -0.00694539],
#        [ 0.01236025, -0.02658564, -0.01747457,  0.0119183 ,  0.00975115],
#        [-0.01582474,  0.00489842,  0.01470408, -0.00365162,  0.00991178],
#        [ 0.00528694,  0.03989155, -0.00163539,  0.0092644 , -0.03514111],
#        [-0.00022122, -0.02615966, -0.00348722, -0.00802786,  0.03068894]])

# %%
pseudoinverse
# Out:
# array([[ 0.00251823,  0.00400527,  0.01148019, -0.00344694, -0.00694539],
#        [ 0.01236025, -0.02658564, -0.01747457,  0.0119183 ,  0.00975115],
#        [-0.01582474,  0.00489842,  0.01470408, -0.00365162,  0.00991178],
#        [ 0.00528694,  0.03989155, -0.00163539,  0.0092644 , -0.03514111],
#        [-0.00022122, -0.02615966, -0.00348722, -0.00802786,  0.03068894]])
